# %%
#Excercise 22 Reading from a file and counting frequencies
#Given a .txt file that has a list of a bunch of names, count how many of each name there are in the file, 
#and print out the results to the screen. 
#I have a .txt file for you, if you want to use it!
#https://www.practicepython.org/exercise/2014/12/06/22-read-from-file.html

'''
Steps: 

   Step1:  Opening the file for reading
   Step2:  Read!
   Sample code: 
    with open('file_to_read.txt', 'r') as open_file:
        all_text = open_file.read()
        
     with open('file_to_read.txt', 'r') as open_file:
         line = open_file.readline()
         while line:
         print(line)
         line = open_file.readline()
'''
darth_count = 0
lea_count = 0
luke_count = 0
with open('Darth_luke.txt','r') as open_file:    ##we know this works
    #chopping_table = open_file.read()            ##we know this works
    
#print(type(chopping_table))                      #we know this works and if print(chopping_table) then in prints. 

    line = open_file.readline()
    #print(line)
    #print("Now print first index")
    #print(line[0])
    
    while line: 
        print(line)
        #print(line[0]=='D')
        if line[0]=='D':
            darth_count+=1
            print("I am Darth")
        elif line=='Lea':
            print("I am Lea")
            lea_count+=1
        else:
            luke_count+=1
            
        line = open_file.readline()
print("Darth_count:{}".format(darth_count))
print("Lea_count:{}".format(lea_count))
print("Luke_count:{}".format(luke_count))
        #print(line[0])
        #if line[0]=='D':
            #darth_count +=1
        #elif: 
            #luke_count +=1
        #else:
    #print("Darth occurance is:{} and luke occurance is: {}".format(darth_count, luke_count))
# Out:
# Darth
#
# I am Darth
# Luke
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Luke
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Luke
#
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Luke
#
# Luke
#
# Lea
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Luke
#
# Lea
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Lea
#
# Lea
#
# Lea
#
# Luke
#
# Darth
#
# I am Darth
# Luke
#
# Lea
#
# Lea
#
# Lea
#
# Lea
#
# Luke
#
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Lea
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Luke
#
# Lea
#
# Luke
#
# Darth
#
# I am Darth
# Darth
#
# I am Darth
# Luke
#
# Darth
#
# I am Darth
# Lea
#
# Darth
#
# I am Darth
# Lea
# ...

# %%
 line = open_file.readline()
    #print(line)
    #print("Now print first index")
    #print(line[0])
    
    while line: 
        print(line)
        #print(line[0]=='D')
        if line[0]=='D':
            darth_count+=1
            print("I am Darth")
        elif line=='Lea':
            print("I am Lea")
            lea_count+=1
        else:
            luke_count+=1
            
        line = open_file.readline()
