# %%
with open('Darth_luke.txt','r') as open_file:    ##we know this works
    #chopping_table = open_file.read()            ##we know this works
    
#print(type(chopping_table))                      #we know this works and if print(chopping_table) then in prints. 

    line = open_file.readline()
    print(len(line))
    first_two = line[0:2:1]
    print(type(first_two))
    Total_record = 0
    Da_count = 0
    Le_count = 0
    Lu_count = 0
    percent = 0.00

    while line: 
        Total_record +=1
        if first_two=='Da':
            print('Da')
            Da_count+=1
        elif first_two=='Le':
            print('Le')
            Le_count+=1
        elif first_two=='Lu':
            print('Lu')
            Lu_count+=1
        else:
            print('Fuck off!!')
        line = open_file.readline()
        first_two = line[0:2:1]
print(f'Darth count is {Da_count} and Darth probablity is {Da_count/Total_record}')
print(f'Lea count is {Le_count} and Lea probability is {Le_count/Total_record}')
print(f'Luke count is {Lu_count} and Luke probability is {Lu_count/Total_record}')
print(f'Total record count is {Total_record}')
# Out:
# 6
# <class 'str'>
# Da
# Lu
# Da
# Le
# Da
# Le
# Le
# Lu
# Da
# Le
# Da
# Da
# Le
# Le
# Da
# Le
# Da
# Le
# Lu
# Da
# Le
# Le
# Da
# Le
# Da
# Da
# Le
# Le
# Lu
# Lu
# Le
# Da
# Da
# Lu
# Le
# Da
# Da
# Le
# Le
# Le
# Le
# Le
# Lu
# Da
# Lu
# Le
# Le
# Le
# Le
# Lu
# Le
# Da
# Le
# Le
# Da
# Le
# Le
# Da
# Da
# Le
# Da
# Le
# Da
# Lu
# Le
# Lu
# Da
# Da
# Lu
# Da
# Le
# Da
# Le
# Lu
# Le
# Le
# Le
# Le
# Le
# Da
# Le
# Le
# Le
# Le
# Le
# Le
# Le
# Lu
# Le
# Le
# Le
# Le
# Le
# Le
# Da
# Lu
# Da
# Le
# Le
# Da
# Darth count is 31 and Darth probablity is 0.31
# Lea count is 54 and Lea probability is 0.54
# Luke count is 15 and Luke probability is 0.15
# Total record count is 100
# Done mother fucker!!
