# %%
#Exercise 21: Take the code from the How To Decode A Website exercise 
#(if you didn’t do it or just want to play with some 
#different code, use the code from the solution), and instead of printing the results to a screen, 
#write the results to a txt file. In your code, just make up a name for the file you are saving to.
#Extras: Ask the user to specify the name of the output file that will be saved.

'''
file = open(“testfile.txt”,”w”) 
 
file.write(“Hello World”) 
file.write(“This is our new text file”) 
file.write(“and this is another line.”) 
file.write(“Why? Because we can.”) 
 
file.close() 

file = open(“testfile.txt”, “r”) 
print file.readlines() 
'''

from bs4 import BeautifulSoup   ##BeautifulSoup will parse once request opens the webpage
import bs4 as bs    ##beautifulsoup4 as bs
import urllib.request  ##urllib module: https://docs.python.org/3/library/urllib.html  =>request is to open and read URL
source = urllib.request.urlopen('https://www.wsj.com/articles/i-found-this-very-very-violent-carlos-ghosns-arrest-tests-nissan-renault-relationship-1542939001').read()   ##you get source code from here.

soup =bs.BeautifulSoup(source,'lxml')   #lxml is the most feature-rich and easy-to-use library for processing XML and HTML in the Python language.
#print(type(soup))
str_soup = str(soup)
#print(type(str_soup))
#print(soup)
#print(soup.title)

#for paragraph in soup.find_all('p'):
    #print(paragraph.text)        #Now save this to a text file you specify
    
for paragraph in soup.find_all('p'):
    #type(paragraph)
    print(paragraph.txt) 
    
    
#print(type(paragraph))
    
'''   
file_name = input("Please provide a name of the file to write the content: ")
print(file_name)
temp_file = open("file_name.txt", "w")
'''

#for paragraph in soup.find_all('title'):
    #print(paragraph.txt)
#for paragraph in soup.find_all('title'):
#   print(paragraph.txt)
#    paragraph_string = str(paragraph.txt)
#    temp_file.write(paragraph_string)        #Now save this to a text file you specify.
    
#temp_file.close()

#print(open("test_file", "r"))


    
    
#%%magic functionality == won't work in other file editor. 
#in Python, file is only 'text' or 'binary'
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# '   \nfile_name = input("Please provide a name of the file to write the content: ")\nprint(file_name)\ntemp_file = open("file_name.txt", "w")\n'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7efcd0391196> in <module>()
# ----> 1 list -la
#
# NameError: name 'la' is not defined

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7049-F55F
#
#  Directory of C:\Users\dicei\Documents\Python3\website_exercises
#
# 11/17/2018  01:44 PM             3,090  Exercise question 2 AddEven.ipynb
# 11/22/2018  07:45 PM    <DIR>          .
# 11/22/2018  07:45 PM    <DIR>          ..
# 11/22/2018  07:58 AM    <DIR>          .ipynb_checkpoints
# 11/19/2018  03:11 PM             1,959 Ex 15 Reverse order of the string via word split .ipynb
# 11/18/2018  08:14 PM             2,035 Excercise 11.ipynb
# 11/18/2018  08:47 PM             2,298 Excercise 12 First_last.ipynb
# 11/18/2018  09:58 PM             1,340 Excercise 13 Fibinachi.ipynb
# 11/19/2018  03:52 PM             2,582 Excercise 16 Generate_password.ipynb
# 11/20/2018  02:02 PM             3,488 Excercise 17 BeautifulSoup.ipynb
# 11/20/2018  08:52 PM             8,262 Excercise 18 Cows_and_bulls().ipynb
# 11/22/2018  07:45 PM             5,995 Excercise 21 write file.ipynb
# ...
