# %%
#Exercise 26:  https://www.practicepython.org/exercise/2015/11/16/26-check-tic-tac-toe.html
#find a single winner     #This works!!
matrix_TTT = [[0,0,0],[0,0,0],[0,0,0]]
#print(matrix_TTT)
'''
game = [[1, 2, 0],
        [2, 1, 0],
        [2, 1, 1]]
    
game = [[1, 2, 0],[2, 1, 0],[2, 1, 1]]

'''
def evaluate_winner(list_input):
#example
    
    winner_is_1 = False
    winner_is_2 = False
    vert_left = []
    vert_mid = []
    vert_right = []
    horiz_top = []
    horiz_mid = []
    horiz_bottom = []
    diag_leftright = []
    diag_rightleft = []

    vert_left.append(game[0][0])
    vert_left.append(game[1][0])
    vert_left.append(game[2][0])
    if vert_left ==[1,1,1] :
        print("winner is player 1 via vertical")
        winner_is_1 = True
    elif vert_left ==[2,2,2] :
        print("winner is player 2 via vertical")
        winner_is_2 = True
    #print(f'vertical left: {vert_left}')

    vert_mid.append(game[0][1])
    vert_mid.append(game[1][1])
    vert_mid.append(game[2][1])
    if vert_mid ==[1,1,1]:
        print("winner is player 1 via vertical")
        winner_is_1 = True
    elif vert_mid ==[2,2,2]:
        print("winner is player 2 via vertical")
        winner_is_2 = True
    #print(f'vertical mid: {vert_mid}')

    vert_right.append(game[0][2])
    vert_right.append(game[1][2])
    vert_right.append(game[2][2])
    if vert_right ==[1,1,1]:
        print("winner is player 1 via vertial")
        winner_is_1 = True
    elif vert_right ==[2,2,2]:
        print("winner is player 2 via vertical")
        winner_is_2 = True
    #print(f'vertical right: {vert_right}')

    for element in game[0]:
        horiz_top.append(element)
    if horiz_top ==[1,1,1]:
        print("winner is player 1 via horizontal")
        winner_is_1 = True
    elif horiz_top ==[2,2,2]:
        print("winner is player 2 via horizontal")
        winner_is_2 = True
    #print(f'horizontal top: {horiz_top}')

    for element in game[1]:
        horiz_mid.append(element)
    if horiz_mid ==[1,1,1]:
        print("winner is player 1 via horizontal")
        winner_is_1 = True
    elif horiz_mid ==[2,2,2]:
        print("winner is player 2 via horizontal")
        winner_is_2 = True
    #print(f'horizontal mid: {horiz_mid}')

    for element in game[2]:
        horiz_bottom.append(element)
    if horiz_bottom ==[1,1,1]:
        print("winner is player 1 via horizontal")
        winner_is_1 = True
    elif horiz_bottom ==[2,2,2]:
        print("winner is player 2 via horizontal")
        winner_is_2 = True
    #print(f'horizontal bottom: {horiz_bottom}')


    #game = [[1, 2, 0],[2, 1, 0],[2, 1, 1]]
    diag_leftright.append(game[0][0])
    diag_leftright.append(game[1][1])
    diag_leftright.append(game[2][2])
    if diag_leftright ==[1,1,1]:
        print("winner is player 1 via diagnal")
        winner_is_1 = True
    elif diag_leftright ==[2,2,2]:
        print("winner is player 2 via diagnal")
        winner_is_2 = True
    #print(f'diagnalLeftToRight{diag_leftright}')
    diag_rightleft.append(game[0][2])
    diag_rightleft.append(game[1][1])
    diag_rightleft.append(game[2][0])
    if diag_rightleft ==[1,1,1]:
        print("winner is player 1 via diagnal")
        winner_is_1 = True
    elif diag_rightleft ==[2,2,2]:
        print("winner is player 2 via diagnal")
        winner_is_2 = True
    #print(f'diagnalRightToLeft{diag_rightleft}')
    if (winner_is_1 == False and winner_is_2==False):
        print("The game was tied!!")



########################################################################################### 
#game = [[1, 2, 0],[2, 1, 0],[2, 1, 1]]
#game = [[2, 2, 2],[2, 1, 0],[2, 1, 1]]
#game = [[1, 2, 0],[1, 2, 0],[2, 2, 1]]
game = [[1, 2, 0],[2, 1, 0],[2, 1, 2]]

evaluate_winner(game)
# Out:
# The game was tied!!
